# %%
#import the dependencies
import pandas as pd
import numpy as np
#import matplotlib.pyplot as plt
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 627

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d9627287f4524613874457d10385800d

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        city_weather = requests.get(city_url).json()
        
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_min_temp = city_weather["main"]["temp_min"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"] 
        try:
            city_rain_inches = city_weather["rain"]["1h"]
        except KeyError:
            city_rain_inches = 0
        try:
            city_snow_inches = city_weather["snow"]["1h"]
        except KeyError:
            city_snow_inches = 0
            
            
#         # Convert the date to ISO standard.
#         city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Min Temp": city_min_temp,
                          "Current Description": city_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Rain (inches)": city_rain_inches,
                          "Snow (inches)": city_snow_inches,
                          "Country": city_country})

        # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
    pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | chumphon
# Processing Record 2 of Set 1 | werda
# Processing Record 3 of Set 1 | new norfolk
# Processing Record 4 of Set 1 | tilichiki
# Processing Record 5 of Set 1 | namibe
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | baherden
# Processing Record 8 of Set 1 | sao filipe
# Processing Record 9 of Set 1 | hamilton
# Processing Record 10 of Set 1 | jamestown
# Processing Record 11 of Set 1 | hobart
# Processing Record 12 of Set 1 | atuona
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | marsh harbour
# Processing Record 15 of Set 1 | port alfred
# Processing Record 16 of Set 1 | rawson
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | saint george
# Processing Record 19 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 1 | tiznit
# Processing Record 21 of Set 1 | albany
# Processing Record 22 of Set 1 | vostok
# Processing Record 23 of Set 1 | bambous virieux
# Processing Record 24 of Set 1 | carnarvon
# Processing Record 25 of Set 1 | namatanai
# Processing Record 26 of Set 1 | cape town
# Processing Record 27 of Set 1 | cockburn town
# Processing Record 28 of Set 1 | makakilo city
# Processing Record 29 of Set 1 | saldanha
# Processing Record 30 of Set 1 | simbahan
# Processing Record 31 of Set 1 | luderitz
# Processing Record 32 of Set 1 | nanortalik
# Processing Record 33 of Set 1 | constitucion
# Processing Record 34 of Set 1 | codrington
# Processing Record 35 of Set 1 | port elizabeth
# Processing Record 36 of Set 1 | pangnirtung
# Processing Record 37 of Set 1 | beringovskiy
# Processing Record 38 of Set 1 | castro
# Processing Record 39 of Set 1 | chase
# Processing Record 40 of Set 1 | kamenka
# Processing Record 41 of Set 1 | bol
# Processing Record 42 of Set 1 | chokurdakh
# Processing Record 43 of Set 1 | bethel
# Processing Record 44 of Set 1 | banda aceh
# Processing Record 45 of Set 1 | kyren
# Processing Record 46 of Set 1 | kapaa
# Processing Record 47 of Set 1 | laguna
# Processing Record 48 of Set 1 | san patricio
# Processing Record 49 of Set 1 | nabul
# City not found. Skipping...
# Processing Record 50 of Set 1 | busselton
# Processing Record 1 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 2 | lebu
# Processing Record 3 of Set 2 | broken hill
# Processing Record 4 of Set 2 | thompson
# Processing Record 5 of Set 2 | mataura
# Processing Record 6 of Set 2 | mount gambier
# Processing Record 7 of Set 2 | san cristobal
# Processing Record 8 of Set 2 | ribeira grande
# Processing Record 9 of Set 2 | manta
# Processing Record 10 of Set 2 | smithers
# Processing Record 11 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 2 | avera
# Processing Record 14 of Set 2 | airai
# Processing Record 15 of Set 2 | yulara
# Processing Record 16 of Set 2 | butaritari
# Processing Record 17 of Set 2 | atambua
# Processing Record 18 of Set 2 | khatanga
# Processing Record 19 of Set 2 | verkhnyaya toyma
# Processing Record 20 of Set 2 | nerkunram
# Processing Record 21 of Set 2 | provideniya
# Processing Record 22 of Set 2 | helong
# Processing Record 23 of Set 2 | tiksi
# Processing Record 24 of Set 2 | vaini
# Processing Record 25 of Set 2 | bereda
# Processing Record 26 of Set 2 | vanderhoof
# Processing Record 27 of Set 2 | yellowknife
# Processing Record 28 of Set 2 | victoria
# Processing Record 29 of Set 2 | cayenne
# Processing Record 30 of Set 2 | nikolskoye
# Processing Record 31 of Set 2 | sofiysk
# City not found. Skipping...
# Processing Record 32 of Set 2 | irbil
# Processing Record 33 of Set 2 | kloulklubed
# Processing Record 34 of Set 2 | mahebourg
# Processing Record 35 of Set 2 | nome
# Processing Record 36 of Set 2 | vila do maio
# Processing Record 37 of Set 2 | madison heights
# Processing Record 38 of Set 2 | hermanus
# Processing Record 39 of Set 2 | port-gentil
# Processing Record 40 of Set 2 | hobyo
# Processing Record 41 of Set 2 | touros
# Processing Record 42 of Set 2 | svetlaya
# Processing Record 43 of Set 2 | jamame
# Processing Record 44 of Set 2 | te anau
# Processing Record 45 of Set 2 | puerto ayora
# Processing Record 46 of Set 2 | riyadh
# Processing Record 47 of Set 2 | husavik
# Processing Record 48 of Set 2 | tasiilaq
# Processing Record 49 of Set 2 | kirkwall
# Processing Record 50 of Set 2 | sovetskiy
# Processing Record 1 of Set 3 | bengkulu
# Processing Record 2 of Set 3 | arraial do cabo
# Processing Record 3 of Set 3 | bluff
# Processing Record 4 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 3 | klaksvik
# Processing Record 6 of Set 3 | grandola
# Processing Record 7 of Set 3 | bambanglipuro
# Processing Record 8 of Set 3 | leningradskiy
# Processing Record 9 of Set 3 | hue
# Processing Record 10 of Set 3 | fortuna
# Processing Record 11 of Set 3 | tunxi
# City not found. Skipping...
# Processing Record 12 of Set 3 | saint-philippe
# Processing Record 13 of Set 3 | saint-joseph
# Processing Record 14 of Set 3 | san javier
# Processing Record 15 of Set 3 | nouadhibou
# Processing Record 16 of Set 3 | talnakh
# Processing Record 17 of Set 3 | matara
# Processing Record 18 of Set 3 | port lincoln
# Processing Record 19 of Set 3 | macapa
# Processing Record 20 of Set 3 | sao gabriel da cachoeira
# Processing Record 21 of Set 3 | nivala
# Processing Record 22 of Set 3 | dovolnoye
# Processing Record 23 of Set 3 | saint-louis
# Processing Record 24 of Set 3 | upernavik
# Processing Record 25 of Set 3 | tuktoyaktuk
# Processing Record 26 of Set 3 | barrow
# Processing Record 27 of Set 3 | tuatapere
# Processing Record 28 of Set 3 | puri
# Processing Record 29 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 30 of Set 3 | coihaique
# Processing Record 31 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 3 | sug-aksy
# City not found. Skipping...
# Processing Record 33 of Set 3 | romny
# Processing Record 34 of Set 3 | guerrero negro
# Processing Record 35 of Set 3 | avarua
# Processing Record 36 of Set 3 | saskylakh
# Processing Record 37 of Set 3 | margate
# Processing Record 38 of Set 3 | eha amufu
# Processing Record 39 of Set 3 | rapid valley
# Processing Record 40 of Set 3 | mareeba
# Processing Record 41 of Set 3 | malazgirt
# Processing Record 42 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 3 | olinda
# Processing Record 44 of Set 3 | cap malheureux
# Processing Record 45 of Set 3 | kahului
# Processing Record 46 of Set 3 | uglich
# Processing Record 47 of Set 3 | qaanaaq
# Processing Record 48 of Set 3 | port keats
# Processing Record 49 of Set 3 | dikson
# Processing Record 50 of Set 3 | beloha
# Processing Record 1 of Set 4 | chatan
# Processing Record 2 of Set 4 | mackay
# Processing Record 3 of Set 4 | longyearbyen
# Processing Record 4 of Set 4 | olds
# Processing Record 5 of Set 4 | ponta do sol
# Processing Record 6 of Set 4 | ngaoundere
# Processing Record 7 of Set 4 | vila franca do campo
# Processing Record 8 of Set 4 | geraldton
# Processing Record 9 of Set 4 | bredasdorp
# Processing Record 10 of Set 4 | hithadhoo
# Processing Record 11 of Set 4 | moranbah
# Processing Record 12 of Set 4 | chapleau
# Processing Record 13 of Set 4 | okmulgee
# Processing Record 14 of Set 4 | sioux lookout
# Processing Record 15 of Set 4 | antofagasta
# Processing Record 16 of Set 4 | plettenberg bay
# Processing Record 17 of Set 4 | sur
# Processing Record 18 of Set 4 | sisimiut
# Processing Record 19 of Set 4 | eyl
# Processing Record 20 of Set 4 | mehamn
# Processing Record 21 of Set 4 | bathsheba
# Processing Record 22 of Set 4 | isangel
# Processing Record 23 of Set 4 | funadhoo
# Processing Record 24 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 4 | hilo
# Processing Record 26 of Set 4 | pemangkat
# Processing Record 27 of Set 4 | norsup
# Processing Record 28 of Set 4 | mahanoro
# Processing Record 29 of Set 4 | comodoro rivadavia
# Processing Record 30 of Set 4 | jieshi
# Processing Record 31 of Set 4 | sanandaj
# Processing Record 32 of Set 4 | awbari
# Processing Record 33 of Set 4 | liwale
# Processing Record 34 of Set 4 | hualmay
# Processing Record 35 of Set 4 | pekan
# Processing Record 36 of Set 4 | cabo san lucas
# Processing Record 37 of Set 4 | gumdag
# Processing Record 38 of Set 4 | hambantota
# Processing Record 39 of Set 4 | baykit
# Processing Record 40 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 41 of Set 4 | kirakira
# Processing Record 42 of Set 4 | makaha
# Processing Record 43 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 4 | muros
# Processing Record 45 of Set 4 | walvis bay
# Processing Record 46 of Set 4 | olafsvik
# Processing Record 47 of Set 4 | san policarpo
# Processing Record 48 of Set 4 | bayangol
# Processing Record 49 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 4 | qovlar
# Processing Record 1 of Set 5 | agaro
# Processing Record 2 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 3 of Set 5 | pevek
# Processing Record 4 of Set 5 | hofn
# Processing Record 5 of Set 5 | techiman
# Processing Record 6 of Set 5 | oulainen
# Processing Record 7 of Set 5 | norman wells
# Processing Record 8 of Set 5 | port-de-bouc
# Processing Record 9 of Set 5 | haines junction
# Processing Record 10 of Set 5 | vardo
# Processing Record 11 of Set 5 | leh
# Processing Record 12 of Set 5 | magdalena
# Processing Record 13 of Set 5 | katsuura
# Processing Record 14 of Set 5 | siilinjarvi
# Processing Record 15 of Set 5 | moindou
# Processing Record 16 of Set 5 | acari
# Processing Record 17 of Set 5 | honiara
# Processing Record 18 of Set 5 | garden city
# Processing Record 19 of Set 5 | shelburne
# Processing Record 20 of Set 5 | samarai
# Processing Record 21 of Set 5 | inhambane
# Processing Record 22 of Set 5 | bojnurd
# Processing Record 23 of Set 5 | kaitangata
# Processing Record 24 of Set 5 | durban
# Processing Record 25 of Set 5 | diffa
# Processing Record 26 of Set 5 | gizo
# Processing Record 27 of Set 5 | bodaybo
# Processing Record 28 of Set 5 | prince george
# Processing Record 29 of Set 5 | ornskoldsvik
# Processing Record 30 of Set 5 | shenkursk
# Processing Record 31 of Set 5 | havoysund
# Processing Record 32 of Set 5 | college
# Processing Record 33 of Set 5 | jumla
# Processing Record 34 of Set 5 | vanavara
# Processing Record 35 of Set 5 | bilibino
# Processing Record 36 of Set 5 | nushki
# Processing Record 37 of Set 5 | omsukchan
# Processing Record 38 of Set 5 | lebyazhye
# Processing Record 39 of Set 5 | grand gaube
# Processing Record 40 of Set 5 | brusturoasa
# Processing Record 41 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 5 | mingguang
# Processing Record 43 of Set 5 | axim
# Processing Record 44 of Set 5 | akhmeta
# Processing Record 45 of Set 5 | borgarnes
# Processing Record 46 of Set 5 | mar del plata
# Processing Record 47 of Set 5 | el dorado
# Processing Record 48 of Set 5 | cherskiy
# Processing Record 49 of Set 5 | sainte-savine
# Processing Record 50 of Set 5 | souillac
# Processing Record 1 of Set 6 | dubbo
# Processing Record 2 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 3 of Set 6 | kodiak
# Processing Record 4 of Set 6 | hit
# Processing Record 5 of Set 6 | barentu
# Processing Record 6 of Set 6 | conde
# Processing Record 7 of Set 6 | loveland
# Processing Record 8 of Set 6 | fairview
# Processing Record 9 of Set 6 | biankouma
# Processing Record 10 of Set 6 | clyde river
# Processing Record 11 of Set 6 | srednekolymsk
# Processing Record 12 of Set 6 | anori
# Processing Record 13 of Set 6 | jimo
# Processing Record 14 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 15 of Set 6 | vao
# Processing Record 16 of Set 6 | mao
# Processing Record 17 of Set 6 | ilhabela
# Processing Record 18 of Set 6 | estelle
# Processing Record 19 of Set 6 | santa rosa
# Processing Record 20 of Set 6 | contamana
# Processing Record 21 of Set 6 | prescott
# Processing Record 22 of Set 6 | nador
# Processing Record 23 of Set 6 | siverek
# Processing Record 24 of Set 6 | kruisfontein
# Processing Record 25 of Set 6 | mwene-ditu
# Processing Record 26 of Set 6 | ahuimanu
# Processing Record 27 of Set 6 | berlevag
# Processing Record 28 of Set 6 | puerto gaitan
# Processing Record 29 of Set 6 | koumac
# Processing Record 30 of Set 6 | palafrugell
# Processing Record 31 of Set 6 | niefern-oschelbronn
# Processing Record 32 of Set 6 | port hawkesbury
# Processing Record 33 of Set 6 | genhe
# Processing Record 34 of Set 6 | westport
# Processing Record 35 of Set 6 | lompoc
# Processing Record 36 of Set 6 | uusikaupunki
# Processing Record 37 of Set 6 | heishan
# Processing Record 38 of Set 6 | coquimbo
# Processing Record 39 of Set 6 | abu samrah
# Processing Record 40 of Set 6 | palana
# Processing Record 41 of Set 6 | pangkalanbuun
# Processing Record 42 of Set 6 | maicao
# Processing Record 43 of Set 6 | leshan
# Processing Record 44 of Set 6 | aripuana
# Processing Record 45 of Set 6 | sorland
# Processing Record 46 of Set 6 | ostrovnoy
# Processing Record 47 of Set 6 | severo-kurilsk
# Processing Record 48 of Set 6 | opuwo
# Processing Record 49 of Set 6 | fort nelson
# Processing Record 50 of Set 6 | the valley
# Processing Record 1 of Set 7 | gundorovskiy
# Processing Record 2 of Set 7 | peleduy
# Processing Record 3 of Set 7 | gushikawa
# Processing Record 4 of Set 7 | iranshahr
# Processing Record 5 of Set 7 | padang
# Processing Record 6 of Set 7 | kostomuksha
# Processing Record 7 of Set 7 | buala
# Processing Record 8 of Set 7 | araouane
# Processing Record 9 of Set 7 | topolobampo
# Processing Record 10 of Set 7 | chuy
# Processing Record 11 of Set 7 | ouadda
# Processing Record 12 of Set 7 | baruun-urt
# Processing Record 13 of Set 7 | goderich
# Processing Record 14 of Set 7 | urdzhar
# City not found. Skipping...
# Processing Record 15 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 16 of Set 7 | ambodifototra
# City not found. Skipping...
# Processing Record 17 of Set 7 | saint-augustin
# Processing Record 18 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 7 | candawaga
# City not found. Skipping...
# Processing Record 20 of Set 7 | mahajanga
# Processing Record 21 of Set 7 | lasa
# Processing Record 22 of Set 7 | derzhavinsk
# Processing Record 23 of Set 7 | petatlan
# Processing Record 24 of Set 7 | dunedin
# Processing Record 25 of Set 7 | umm lajj
# Processing Record 26 of Set 7 | villa del rosario
# Processing Record 27 of Set 7 | torbay
# Processing Record 28 of Set 7 | seabra
# Processing Record 29 of Set 7 | bitung
# Processing Record 30 of Set 7 | mindelo
# Processing Record 31 of Set 7 | sisophon
# Processing Record 32 of Set 7 | port augusta
# Processing Record 33 of Set 7 | plouzane
# Processing Record 34 of Set 7 | warrnambool
# Processing Record 35 of Set 7 | vallenar
# Processing Record 36 of Set 7 | pacific grove
# Processing Record 37 of Set 7 | ust-maya
# Processing Record 38 of Set 7 | north bend
# Processing Record 39 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 40 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 41 of Set 7 | tynda
# Processing Record 42 of Set 7 | faanui
# Processing Record 43 of Set 7 | caravelas
# Processing Record 44 of Set 7 | bucine
# Processing Record 45 of Set 7 | ambon
# Processing Record 46 of Set 7 | fare
# Processing Record 47 of Set 7 | antalaha
# Processing Record 48 of Set 7 | shimoda
# Processing Record 49 of Set 7 | santa cruz del norte
# Processing Record 50 of Set 7 | karaton
# Processing Record 1 of Set 8 | corrales
# Processing Record 2 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 8 | kaohsiung
# Processing Record 4 of Set 8 | mogadishu
# Processing Record 5 of Set 8 | tromso
# Processing Record 6 of Set 8 | havelock
# Processing Record 7 of Set 8 | portland
# Processing Record 8 of Set 8 | ilulissat
# Processing Record 9 of Set 8 | orlik
# Processing Record 10 of Set 8 | yerbogachen
# Processing Record 11 of Set 8 | leninskoye
# Processing Record 12 of Set 8 | labuhan
# Processing Record 13 of Set 8 | raudeberg
# Processing Record 14 of Set 8 | nemuro
# Processing Record 15 of Set 8 | roebourne
# Processing Record 16 of Set 8 | arcata
# Processing Record 17 of Set 8 | sobolevo
# Processing Record 18 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 19 of Set 8 | guarapari
# Processing Record 20 of Set 8 | zhatay
# Processing Record 21 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 22 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 8 | the pas
# Processing Record 24 of Set 8 | oranjestad
# Processing Record 25 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 8 | talah
# City not found. Skipping...
# Processing Record 27 of Set 8 | dauphin
# Processing Record 28 of Set 8 | kudahuvadhoo
# Processing Record 29 of Set 8 | yuli
# Processing Record 30 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 31 of Set 8 | georgetown
# Processing Record 32 of Set 8 | rabo de peixe
# Processing Record 33 of Set 8 | montepulciano
# Processing Record 34 of Set 8 | maine-soroa
# Processing Record 35 of Set 8 | east london
# Processing Record 36 of Set 8 | ekhabi
# Processing Record 37 of Set 8 | havre
# Processing Record 38 of Set 8 | soyo
# Processing Record 39 of Set 8 | tigil
# Processing Record 40 of Set 8 | flinders
# Processing Record 41 of Set 8 | mersing
# Processing Record 42 of Set 8 | bousse
# Processing Record 43 of Set 8 | sangar
# Processing Record 44 of Set 8 | basay
# Processing Record 45 of Set 8 | rockhampton
# Processing Record 46 of Set 8 | la ronge
# Processing Record 47 of Set 8 | tasbuget
# City not found. Skipping...
# Processing Record 48 of Set 8 | arbazh
# Processing Record 49 of Set 8 | talcahuano
# Processing Record 50 of Set 8 | leua
# Processing Record 1 of Set 9 | dingle
# Processing Record 2 of Set 9 | necochea
# Processing Record 3 of Set 9 | pirovskoye
# Processing Record 4 of Set 9 | alyangula
# Processing Record 5 of Set 9 | muisne
# Processing Record 6 of Set 9 | bilma
# Processing Record 7 of Set 9 | cidreira
# Processing Record 8 of Set 9 | saint anthony
# Processing Record 9 of Set 9 | graciano sanchez
# Processing Record 10 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 9 | zadar
# Processing Record 12 of Set 9 | tucurui
# Processing Record 13 of Set 9 | luba
# Processing Record 14 of Set 9 | preobrazheniye
# Processing Record 15 of Set 9 | sao joao da barra
# Processing Record 16 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 17 of Set 9 | tessalit
# Processing Record 18 of Set 9 | ler
# Processing Record 19 of Set 9 | lorengau
# Processing Record 20 of Set 9 | armacao dos buzios
# City not found. Skipping...
# Processing Record 21 of Set 9 | qandala
# Processing Record 22 of Set 9 | san juan del sur
# Processing Record 23 of Set 9 | wahran
# City not found. Skipping...
# Processing Record 24 of Set 9 | umm kaddadah
# Processing Record 25 of Set 9 | vestmannaeyjar
# Processing Record 26 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 9 | allende
# Processing Record 28 of Set 9 | stoholm
# Processing Record 29 of Set 9 | tonantins
# Processing Record 30 of Set 9 | montrose
# Processing Record 31 of Set 9 | chadiza
# Processing Record 32 of Set 9 | mizan teferi
# Processing Record 33 of Set 9 | okhotsk
# Processing Record 34 of Set 9 | belaya gora
# Processing Record 35 of Set 9 | nuuk
# Processing Record 36 of Set 9 | lugovoy
# Processing Record 37 of Set 9 | santa maria da vitoria
# Processing Record 38 of Set 9 | lavrentiya
# Processing Record 39 of Set 9 | waipawa
# Processing Record 40 of Set 9 | nishihara
# Processing Record 41 of Set 9 | khor
# Processing Record 42 of Set 9 | shingu
# Processing Record 43 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 44 of Set 9 | ust-kuyga
# Processing Record 45 of Set 9 | itaperuna
# Processing Record 46 of Set 9 | arlit
# Processing Record 47 of Set 9 | bima
# Processing Record 48 of Set 9 | varnavino
# Processing Record 49 of Set 9 | ponta delgada
# Processing Record 50 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 10 | port shepstone
# Processing Record 2 of Set 10 | cairns
# Processing Record 3 of Set 10 | matamoros
# Processing Record 4 of Set 10 | hohenems
# Processing Record 5 of Set 10 | tarko-sale
# Processing Record 6 of Set 10 | anzio
# Processing Record 7 of Set 10 | sechura
# Processing Record 8 of Set 10 | belyy yar
# Processing Record 9 of Set 10 | pisco
# Processing Record 10 of Set 10 | emerald
# Processing Record 11 of Set 10 | villafranca de los barros
# Processing Record 12 of Set 10 | fuyang
# Processing Record 13 of Set 10 | ngunguru
# Processing Record 14 of Set 10 | dalmine
# Processing Record 15 of Set 10 | matagami
# Processing Record 16 of Set 10 | utiel
# Processing Record 17 of Set 10 | soller
# Processing Record 18 of Set 10 | filimonovo
# Processing Record 19 of Set 10 | san luis de gaceno
# Processing Record 20 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 10 | yar-sale
# Processing Record 22 of Set 10 | bulungu
# Processing Record 23 of Set 10 | visby
# Processing Record 24 of Set 10 | sydney mines
# Processing Record 25 of Set 10 | waterloo
# Processing Record 26 of Set 10 | savannah bight
# Processing Record 27 of Set 10 | marzuq
# Processing Record 28 of Set 10 | buqayq
# City not found. Skipping...
# Processing Record 29 of Set 10 | tagusao
# Processing Record 30 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 31 of Set 10 | pervomayskiy
# Processing Record 32 of Set 10 | paamiut
# Processing Record 33 of Set 10 | dalvik
# Processing Record 34 of Set 10 | nizwa
# Processing Record 35 of Set 10 | japura
# Processing Record 36 of Set 10 | aksu
# Processing Record 37 of Set 10 | qinzhou
# Processing Record 38 of Set 10 | kamina
# Processing Record 39 of Set 10 | adrar
# Processing Record 40 of Set 10 | santa helena
# Processing Record 41 of Set 10 | gaspe
# Processing Record 42 of Set 10 | paita
# Processing Record 43 of Set 10 | phalombe
# Processing Record 44 of Set 10 | narsaq
# Processing Record 45 of Set 10 | lagos
# Processing Record 46 of Set 10 | balkanabat
# Processing Record 47 of Set 10 | kulhudhuffushi
# Processing Record 48 of Set 10 | yenagoa
# Processing Record 49 of Set 10 | namtsy
# Processing Record 50 of Set 10 | maceio
# Processing Record 1 of Set 11 | dogbo
# Processing Record 2 of Set 11 | phonhong
# Processing Record 3 of Set 11 | hami
# Processing Record 4 of Set 11 | kavieng
# Processing Record 5 of Set 11 | faya
# Processing Record 6 of Set 11 | grogol
# Processing Record 7 of Set 11 | solsvik
# City not found. Skipping...
# Processing Record 8 of Set 11 | port blair
# Processing Record 9 of Set 11 | hohhot
# Processing Record 10 of Set 11 | vagur
# Processing Record 11 of Set 11 | bobo dioulasso
# Processing Record 12 of Set 11 | puno
# Processing Record 13 of Set 11 | sosnovskiy
# City not found. Skipping...
# Processing Record 14 of Set 11 | azimur
# City not found. Skipping...
# Processing Record 15 of Set 11 | bokspits
# City not found. Skipping...
# Processing Record 16 of Set 11 | tahta
# Processing Record 17 of Set 11 | parana
# Processing Record 18 of Set 11 | takoradi
# Processing Record 19 of Set 11 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 20 of Set 11 | sosnogorsk
# Processing Record 21 of Set 11 | ballina
# Processing Record 22 of Set 11 | calabozo
# Processing Record 23 of Set 11 | rumphi
# Processing Record 24 of Set 11 | fallon
# Processing Record 25 of Set 11 | abu kamal
# Processing Record 26 of Set 11 | belmonte
# Processing Record 27 of Set 11 | banjar
# Processing Record 28 of Set 11 | kaeo
# Processing Record 29 of Set 11 | ankazoabo
# Processing Record 30 of Set 11 | tahe
# Processing Record 31 of Set 11 | emirdag
# Processing Record 32 of Set 11 | panjab
# Processing Record 33 of Set 11 | harper
# Processing Record 34 of Set 11 | mount darwin
# Processing Record 35 of Set 11 | nuevitas
# Processing Record 36 of Set 11 | lagoa
# Processing Record 37 of Set 11 | porto novo
# Processing Record 38 of Set 11 | victoria point
# Processing Record 39 of Set 11 | kutum
# Processing Record 40 of Set 11 | alekseyevka
# Processing Record 41 of Set 11 | bucerias
# Processing Record 42 of Set 11 | eureka
# Processing Record 43 of Set 11 | ulladulla
# Processing Record 44 of Set 11 | kamaishi
# Processing Record 45 of Set 11 | upington
# Processing Record 46 of Set 11 | uthal
# Processing Record 47 of Set 11 | wellington
# Processing Record 48 of Set 11 | richards bay
# Processing Record 49 of Set 11 | ukiah
# Processing Record 50 of Set 11 | manokwari
# Processing Record 1 of Set 12 | suluktu
# Processing Record 2 of Set 12 | challans
# Processing Record 3 of Set 12 | fraserburgh
# Processing Record 4 of Set 12 | salym
# Processing Record 5 of Set 12 | iqaluit
# Processing Record 6 of Set 12 | la maddalena
# Processing Record 7 of Set 12 | peniche
# Processing Record 8 of Set 12 | yuzhnyy
# Processing Record 9 of Set 12 | vilyuysk
# Processing Record 10 of Set 12 | wakefield
# Processing Record 11 of Set 12 | nelson bay
# Processing Record 12 of Set 12 | mirpur bathoro
# City not found. Skipping...
# Processing Record 13 of Set 12 | kargapolye
# City not found. Skipping...
# Processing Record 14 of Set 12 | toamasina
# Processing Record 15 of Set 12 | polunochnoye
# Processing Record 16 of Set 12 | presidencia roque saenz pena
# Processing Record 17 of Set 12 | karratha
# Processing Record 18 of Set 12 | rudnichnyy
# Processing Record 19 of Set 12 | chacabuco
# Processing Record 20 of Set 12 | lagunas
# Processing Record 21 of Set 12 | chillicothe
# Processing Record 22 of Set 12 | lahaina
# Processing Record 23 of Set 12 | alofi
# Processing Record 24 of Set 12 | along
# Processing Record 25 of Set 12 | obihiro
# Processing Record 26 of Set 12 | tondano
# Processing Record 27 of Set 12 | zhigansk
# Processing Record 28 of Set 12 | shache
# Processing Record 29 of Set 12 | shestakovo
# Processing Record 30 of Set 12 | zyryanka
# Processing Record 31 of Set 12 | posse
# Processing Record 32 of Set 12 | joao pinheiro
# Processing Record 33 of Set 12 | pimentel
# Processing Record 34 of Set 12 | batagay-alyta
# Processing Record 35 of Set 12 | plainview
# Processing Record 36 of Set 12 | maningrida
# Processing Record 37 of Set 12 | taywarah
# Processing Record 38 of Set 12 | mlonggo
# Processing Record 39 of Set 12 | chernyshevskiy
# Processing Record 40 of Set 12 | inta
# Processing Record 41 of Set 12 | krasnoarmeyskoye
# Processing Record 42 of Set 12 | tazovskiy
# Processing Record 43 of Set 12 | arman
# Processing Record 44 of Set 12 | guaruja
# Processing Record 45 of Set 12 | russell
# Processing Record 46 of Set 12 | halifax
# Processing Record 47 of Set 12 | vrangel
# Processing Record 48 of Set 12 | alta floresta
# Processing Record 49 of Set 12 | chabahar
# Processing Record 50 of Set 12 | taraza
# Processing Record 1 of Set 13 | oktyabrskiy
# Processing Record 2 of Set 13 | hasaki
# Processing Record 3 of Set 13 | huarmey
# Processing Record 4 of Set 13 | yichun
# Processing Record 5 of Set 13 | matiari
# Processing Record 6 of Set 13 | rudnik
# Processing Record 7 of Set 13 | lamu
# Processing Record 8 of Set 13 | mayo
# Processing Record 9 of Set 13 | kytlym
# City not found. Skipping...
# Processing Record 10 of Set 13 | pochutla
# Processing Record 11 of Set 13 | pokhara
# Processing Record 12 of Set 13 | oranjemund
# Processing Record 13 of Set 13 | namwala
# Processing Record 14 of Set 13 | pathankot
# Processing Record 15 of Set 13 | millinocket
# Processing Record 16 of Set 13 | asfi
# Processing Record 17 of Set 13 | komsomolskiy
# Processing Record 18 of Set 13 | quatre cocos
# Processing Record 19 of Set 13 | cabanas
# Processing Record 20 of Set 13 | baraki barak
# Processing Record 21 of Set 13 | parfenyevo
# Processing Record 22 of Set 13 | ternate
# Processing Record 23 of Set 13 | egvekinot
# Processing Record 24 of Set 13 | mangile
# City not found. Skipping...
# Processing Record 25 of Set 13 | vanimo
# Processing Record 26 of Set 13 | prince rupert
# Processing Record 27 of Set 13 | zhangjiakou
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 574

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City    Lat     Lng  Max Temp  Min Temp Current Description  \
# 0      Chumphon  10.33   98.83     78.80     78.80       broken clouds
# 1         Werda -25.27   23.28     35.04     35.04           clear sky
# 2   New Norfolk -42.78  147.06     48.00     41.00     overcast clouds
# 3     Tilichiki  60.47  166.10     51.55     51.55     overcast clouds
# 4        Namibe -15.20   12.15     61.61     61.61           clear sky
# 5  Punta Arenas -53.15  -70.92     32.00     32.00     overcast clouds
# 6      Baherden  38.44   57.43     84.72     84.72           clear sky
# 7    Sao Filipe  14.90  -24.50     77.92     77.92       broken clouds
# 8      Hamilton  39.18  -84.53     82.00     77.00          few clouds
# 9     Jamestown  42.10  -79.24     71.01     66.00           clear sky
#
#    Humidity  Cloudiness  Wind Speed  Rain (inches)  Snow (inches) Country
# 0        94          75        1.57            0.0              0      TH
# 1        80           0        8.14            0.0              0      BW
# 2        92         100        0.38            0.0              0      AU
# 3        91         100        5.99            0.0              0      RU
# 4        85           0        1.83            0.0              0      AO
# 5        86          99        4.70            0.0              0      CL
# 6        42           0        6.06            0.0              0      TM
# 7        83          80        6.89            0.0              0      CV
# 8        65          20        5.10            0.0              0      US
# 9        64           1        5.82            0.0              0      US

# %%
# Save DF as a CSV
city_data_df.to_csv('Weatherpy_database.csv')
